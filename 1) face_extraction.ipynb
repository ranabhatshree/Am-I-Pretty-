# %%
import cv2
import numpy as np
import os 
import matplotlib.pyplot as plt

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('xml/haarcascade_frontalface_default.xml')

# %%
def extract_face(img_path):
    img = cv2.imread(img_path)
    
    if type(img) == np.ndarray:
        # Convert into grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Detect faces
        faces = face_cascade.detectMultiScale(gray, 1.1, 4)

        if len(faces) > 0:
            img_crop = 0
            for (x, y, w, h) in faces:
                img_crop = img[y:y+h, x:x+w]
            return img_crop
        else:
            print("Sorry! No Face Detected.")
            return []
    else:
        return []

# %%
def create_dir(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

# %%
# Loading Random Pictures Downloaded From Google

path = "data_collected_from_google"
classes = ['pretty', 'not_pretty']
save_to = "data_cascaded"
img_height = 80
img_width = 80
img_channel = 3

# %%
# Get all images from directories and extract faces only
def extract_images(source, destination):
    for my_dir in os.listdir(source):
        dir_name = os.path.join(destination, my_dir)
        create_dir(dir_name)
        print("{} created success..".format(dir_name))
        curr_dir = os.path.join(source, my_dir)
        i = 0
        for file in os.listdir(curr_dir):
            file = os.path.join(curr_dir, file)
            face_only = extract_face(file)
            if len(face_only) > 0:
                # resizing
                face_only = cv2.resize(face_only, (img_width, img_height))
                img_name = "{}.jpg".format(i)
                cv2.imwrite(os.path.join(dir_name, img_name) , face_only)
                print("{} written to {} success".format(img_name, curr_dir))
                i += 1

# %%
extract_images(path, save_to)
# Out:
# data_cascaded\not_pretty created success..
# 0.jpg written to data_collected_from_google\not_pretty success
# 1.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 2.jpg written to data_collected_from_google\not_pretty success
# 3.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 4.jpg written to data_collected_from_google\not_pretty success
# 5.jpg written to data_collected_from_google\not_pretty success
# 6.jpg written to data_collected_from_google\not_pretty success
# 7.jpg written to data_collected_from_google\not_pretty success
# 8.jpg written to data_collected_from_google\not_pretty success
# 9.jpg written to data_collected_from_google\not_pretty success
# 10.jpg written to data_collected_from_google\not_pretty success
# 11.jpg written to data_collected_from_google\not_pretty success
# 12.jpg written to data_collected_from_google\not_pretty success
# 13.jpg written to data_collected_from_google\not_pretty success
# 14.jpg written to data_collected_from_google\not_pretty success
# 15.jpg written to data_collected_from_google\not_pretty success
# 16.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 17.jpg written to data_collected_from_google\not_pretty success
# 18.jpg written to data_collected_from_google\not_pretty success
# 19.jpg written to data_collected_from_google\not_pretty success
# 20.jpg written to data_collected_from_google\not_pretty success
# 21.jpg written to data_collected_from_google\not_pretty success
# 22.jpg written to data_collected_from_google\not_pretty success
# 23.jpg written to data_collected_from_google\not_pretty success
# 24.jpg written to data_collected_from_google\not_pretty success
# 25.jpg written to data_collected_from_google\not_pretty success
# 26.jpg written to data_collected_from_google\not_pretty success
# 27.jpg written to data_collected_from_google\not_pretty success
# 28.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 29.jpg written to data_collected_from_google\not_pretty success
# 30.jpg written to data_collected_from_google\not_pretty success
# 31.jpg written to data_collected_from_google\not_pretty success
# 32.jpg written to data_collected_from_google\not_pretty success
# 33.jpg written to data_collected_from_google\not_pretty success
# 34.jpg written to data_collected_from_google\not_pretty success
# 35.jpg written to data_collected_from_google\not_pretty success
# 36.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 37.jpg written to data_collected_from_google\not_pretty success
# 38.jpg written to data_collected_from_google\not_pretty success
# 39.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 40.jpg written to data_collected_from_google\not_pretty success
# 41.jpg written to data_collected_from_google\not_pretty success
# 42.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 43.jpg written to data_collected_from_google\not_pretty success
# 44.jpg written to data_collected_from_google\not_pretty success
# 45.jpg written to data_collected_from_google\not_pretty success
# 46.jpg written to data_collected_from_google\not_pretty success
# 47.jpg written to data_collected_from_google\not_pretty success
# 48.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 49.jpg written to data_collected_from_google\not_pretty success
# 50.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 51.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 52.jpg written to data_collected_from_google\not_pretty success
# 53.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 54.jpg written to data_collected_from_google\not_pretty success
# 55.jpg written to data_collected_from_google\not_pretty success
# 56.jpg written to data_collected_from_google\not_pretty success
# 57.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 58.jpg written to data_collected_from_google\not_pretty success
# 59.jpg written to data_collected_from_google\not_pretty success
# 60.jpg written to data_collected_from_google\not_pretty success
# 61.jpg written to data_collected_from_google\not_pretty success
# 62.jpg written to data_collected_from_google\not_pretty success
# 63.jpg written to data_collected_from_google\not_pretty success
# 64.jpg written to data_collected_from_google\not_pretty success
# 65.jpg written to data_collected_from_google\not_pretty success
# 66.jpg written to data_collected_from_google\not_pretty success
# 67.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 68.jpg written to data_collected_from_google\not_pretty success
# 69.jpg written to data_collected_from_google\not_pretty success
# 70.jpg written to data_collected_from_google\not_pretty success
# 71.jpg written to data_collected_from_google\not_pretty success
# 72.jpg written to data_collected_from_google\not_pretty success
# 73.jpg written to data_collected_from_google\not_pretty success
# 74.jpg written to data_collected_from_google\not_pretty success
# 75.jpg written to data_collected_from_google\not_pretty success
# 76.jpg written to data_collected_from_google\not_pretty success
# 77.jpg written to data_collected_from_google\not_pretty success
# 78.jpg written to data_collected_from_google\not_pretty success
# 79.jpg written to data_collected_from_google\not_pretty success
# 80.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 81.jpg written to data_collected_from_google\not_pretty success
# 82.jpg written to data_collected_from_google\not_pretty success
# 83.jpg written to data_collected_from_google\not_pretty success
# 84.jpg written to data_collected_from_google\not_pretty success
# 85.jpg written to data_collected_from_google\not_pretty success
# 86.jpg written to data_collected_from_google\not_pretty success
# 87.jpg written to data_collected_from_google\not_pretty success
# 88.jpg written to data_collected_from_google\not_pretty success
# 89.jpg written to data_collected_from_google\not_pretty success
# 90.jpg written to data_collected_from_google\not_pretty success
# 91.jpg written to data_collected_from_google\not_pretty success
# 92.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 93.jpg written to data_collected_from_google\not_pretty success
# 94.jpg written to data_collected_from_google\not_pretty success
# 95.jpg written to data_collected_from_google\not_pretty success
# 96.jpg written to data_collected_from_google\not_pretty success
# 97.jpg written to data_collected_from_google\not_pretty success
# 98.jpg written to data_collected_from_google\not_pretty success
# 99.jpg written to data_collected_from_google\not_pretty success
# 100.jpg written to data_collected_from_google\not_pretty success
# 101.jpg written to data_collected_from_google\not_pretty success
# 102.jpg written to data_collected_from_google\not_pretty success
# 103.jpg written to data_collected_from_google\not_pretty success
# 104.jpg written to data_collected_from_google\not_pretty success
# 105.jpg written to data_collected_from_google\not_pretty success
# 106.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 107.jpg written to data_collected_from_google\not_pretty success
# 108.jpg written to data_collected_from_google\not_pretty success
# 109.jpg written to data_collected_from_google\not_pretty success
# 110.jpg written to data_collected_from_google\not_pretty success
# 111.jpg written to data_collected_from_google\not_pretty success
# 112.jpg written to data_collected_from_google\not_pretty success
# 113.jpg written to data_collected_from_google\not_pretty success
# 114.jpg written to data_collected_from_google\not_pretty success
# 115.jpg written to data_collected_from_google\not_pretty success
# 116.jpg written to data_collected_from_google\not_pretty success
# 117.jpg written to data_collected_from_google\not_pretty success
# 118.jpg written to data_collected_from_google\not_pretty success
# 119.jpg written to data_collected_from_google\not_pretty success
# 120.jpg written to data_collected_from_google\not_pretty success
# 121.jpg written to data_collected_from_google\not_pretty success
# 122.jpg written to data_collected_from_google\not_pretty success
# 123.jpg written to data_collected_from_google\not_pretty success
# 124.jpg written to data_collected_from_google\not_pretty success
# 125.jpg written to data_collected_from_google\not_pretty success
# 126.jpg written to data_collected_from_google\not_pretty success
# 127.jpg written to data_collected_from_google\not_pretty success
# 128.jpg written to data_collected_from_google\not_pretty success
# 129.jpg written to data_collected_from_google\not_pretty success
# 130.jpg written to data_collected_from_google\not_pretty success
# 131.jpg written to data_collected_from_google\not_pretty success
# 132.jpg written to data_collected_from_google\not_pretty success
# 133.jpg written to data_collected_from_google\not_pretty success
# 134.jpg written to data_collected_from_google\not_pretty success
# 135.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 136.jpg written to data_collected_from_google\not_pretty success
# 137.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 138.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 139.jpg written to data_collected_from_google\not_pretty success
# 140.jpg written to data_collected_from_google\not_pretty success
# 141.jpg written to data_collected_from_google\not_pretty success
# 142.jpg written to data_collected_from_google\not_pretty success
# 143.jpg written to data_collected_from_google\not_pretty success
# 144.jpg written to data_collected_from_google\not_pretty success
# 145.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 146.jpg written to data_collected_from_google\not_pretty success
# 147.jpg written to data_collected_from_google\not_pretty success
# 148.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 149.jpg written to data_collected_from_google\not_pretty success
# 150.jpg written to data_collected_from_google\not_pretty success
# 151.jpg written to data_collected_from_google\not_pretty success
# 152.jpg written to data_collected_from_google\not_pretty success
# 153.jpg written to data_collected_from_google\not_pretty success
# 154.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 155.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 156.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 157.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 158.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 159.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 160.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 161.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 162.jpg written to data_collected_from_google\not_pretty success
# 163.jpg written to data_collected_from_google\not_pretty success
# 164.jpg written to data_collected_from_google\not_pretty success
# 165.jpg written to data_collected_from_google\not_pretty success
# 166.jpg written to data_collected_from_google\not_pretty success
# 167.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 168.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 169.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 170.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 171.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 172.jpg written to data_collected_from_google\not_pretty success
# 173.jpg written to data_collected_from_google\not_pretty success
# 174.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 175.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 176.jpg written to data_collected_from_google\not_pretty success
# 177.jpg written to data_collected_from_google\not_pretty success
# 178.jpg written to data_collected_from_google\not_pretty success
# 179.jpg written to data_collected_from_google\not_pretty success
# 180.jpg written to data_collected_from_google\not_pretty success
# 181.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 182.jpg written to data_collected_from_google\not_pretty success
# 183.jpg written to data_collected_from_google\not_pretty success
# 184.jpg written to data_collected_from_google\not_pretty success
# 185.jpg written to data_collected_from_google\not_pretty success
# 186.jpg written to data_collected_from_google\not_pretty success
# 187.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 188.jpg written to data_collected_from_google\not_pretty success
# 189.jpg written to data_collected_from_google\not_pretty success
# 190.jpg written to data_collected_from_google\not_pretty success
# 191.jpg written to data_collected_from_google\not_pretty success
# 192.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 193.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 194.jpg written to data_collected_from_google\not_pretty success
# 195.jpg written to data_collected_from_google\not_pretty success
# 196.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 197.jpg written to data_collected_from_google\not_pretty success
# 198.jpg written to data_collected_from_google\not_pretty success
# 199.jpg written to data_collected_from_google\not_pretty success
# 200.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 201.jpg written to data_collected_from_google\not_pretty success
# 202.jpg written to data_collected_from_google\not_pretty success
# 203.jpg written to data_collected_from_google\not_pretty success
# 204.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 205.jpg written to data_collected_from_google\not_pretty success
# 206.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 207.jpg written to data_collected_from_google\not_pretty success
# 208.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 209.jpg written to data_collected_from_google\not_pretty success
# 210.jpg written to data_collected_from_google\not_pretty success
# 211.jpg written to data_collected_from_google\not_pretty success
# 212.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 213.jpg written to data_collected_from_google\not_pretty success
# 214.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 215.jpg written to data_collected_from_google\not_pretty success
# 216.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 217.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 218.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 219.jpg written to data_collected_from_google\not_pretty success
# 220.jpg written to data_collected_from_google\not_pretty success
# 221.jpg written to data_collected_from_google\not_pretty success
# 222.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 223.jpg written to data_collected_from_google\not_pretty success
# 224.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 225.jpg written to data_collected_from_google\not_pretty success
# 226.jpg written to data_collected_from_google\not_pretty success
# 227.jpg written to data_collected_from_google\not_pretty success
# 228.jpg written to data_collected_from_google\not_pretty success
# 229.jpg written to data_collected_from_google\not_pretty success
# 230.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 231.jpg written to data_collected_from_google\not_pretty success
# 232.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 233.jpg written to data_collected_from_google\not_pretty success
# 234.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 235.jpg written to data_collected_from_google\not_pretty success
# 236.jpg written to data_collected_from_google\not_pretty success
# 237.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 238.jpg written to data_collected_from_google\not_pretty success
# 239.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 240.jpg written to data_collected_from_google\not_pretty success
# 241.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 242.jpg written to data_collected_from_google\not_pretty success
# 243.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 244.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 245.jpg written to data_collected_from_google\not_pretty success
# 246.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 247.jpg written to data_collected_from_google\not_pretty success
# 248.jpg written to data_collected_from_google\not_pretty success
# 249.jpg written to data_collected_from_google\not_pretty success
# 250.jpg written to data_collected_from_google\not_pretty success
# 251.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 252.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 253.jpg written to data_collected_from_google\not_pretty success
# 254.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 255.jpg written to data_collected_from_google\not_pretty success
# 256.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 257.jpg written to data_collected_from_google\not_pretty success
# 258.jpg written to data_collected_from_google\not_pretty success
# 259.jpg written to data_collected_from_google\not_pretty success
# 260.jpg written to data_collected_from_google\not_pretty success
# 261.jpg written to data_collected_from_google\not_pretty success
# 262.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 263.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 264.jpg written to data_collected_from_google\not_pretty success
# 265.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 266.jpg written to data_collected_from_google\not_pretty success
# 267.jpg written to data_collected_from_google\not_pretty success
# 268.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 269.jpg written to data_collected_from_google\not_pretty success
# 270.jpg written to data_collected_from_google\not_pretty success
# 271.jpg written to data_collected_from_google\not_pretty success
# 272.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 273.jpg written to data_collected_from_google\not_pretty success
# 274.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 275.jpg written to data_collected_from_google\not_pretty success
# 276.jpg written to data_collected_from_google\not_pretty success
# 277.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 278.jpg written to data_collected_from_google\not_pretty success
# 279.jpg written to data_collected_from_google\not_pretty success
# 280.jpg written to data_collected_from_google\not_pretty success
# 281.jpg written to data_collected_from_google\not_pretty success
# 282.jpg written to data_collected_from_google\not_pretty success
# 283.jpg written to data_collected_from_google\not_pretty success
# 284.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 285.jpg written to data_collected_from_google\not_pretty success
# 286.jpg written to data_collected_from_google\not_pretty success
# 287.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 288.jpg written to data_collected_from_google\not_pretty success
# 289.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 290.jpg written to data_collected_from_google\not_pretty success
# 291.jpg written to data_collected_from_google\not_pretty success
# 292.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 293.jpg written to data_collected_from_google\not_pretty success
# 294.jpg written to data_collected_from_google\not_pretty success
# 295.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 296.jpg written to data_collected_from_google\not_pretty success
# 297.jpg written to data_collected_from_google\not_pretty success
# 298.jpg written to data_collected_from_google\not_pretty success
# 299.jpg written to data_collected_from_google\not_pretty success
# 300.jpg written to data_collected_from_google\not_pretty success
# 301.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 302.jpg written to data_collected_from_google\not_pretty success
# 303.jpg written to data_collected_from_google\not_pretty success
# 304.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 305.jpg written to data_collected_from_google\not_pretty success
# 306.jpg written to data_collected_from_google\not_pretty success
# 307.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 308.jpg written to data_collected_from_google\not_pretty success
# 309.jpg written to data_collected_from_google\not_pretty success
# 310.jpg written to data_collected_from_google\not_pretty success
# 311.jpg written to data_collected_from_google\not_pretty success
# 312.jpg written to data_collected_from_google\not_pretty success
# 313.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 314.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 315.jpg written to data_collected_from_google\not_pretty success
# 316.jpg written to data_collected_from_google\not_pretty success
# 317.jpg written to data_collected_from_google\not_pretty success
# 318.jpg written to data_collected_from_google\not_pretty success
# 319.jpg written to data_collected_from_google\not_pretty success
# 320.jpg written to data_collected_from_google\not_pretty success
# 321.jpg written to data_collected_from_google\not_pretty success
# 322.jpg written to data_collected_from_google\not_pretty success
# 323.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 324.jpg written to data_collected_from_google\not_pretty success
# 325.jpg written to data_collected_from_google\not_pretty success
# 326.jpg written to data_collected_from_google\not_pretty success
# 327.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 328.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 329.jpg written to data_collected_from_google\not_pretty success
# 330.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 331.jpg written to data_collected_from_google\not_pretty success
# 332.jpg written to data_collected_from_google\not_pretty success
# 333.jpg written to data_collected_from_google\not_pretty success
# 334.jpg written to data_collected_from_google\not_pretty success
# 335.jpg written to data_collected_from_google\not_pretty success
# 336.jpg written to data_collected_from_google\not_pretty success
# 337.jpg written to data_collected_from_google\not_pretty success
# 338.jpg written to data_collected_from_google\not_pretty success
# 339.jpg written to data_collected_from_google\not_pretty success
# 340.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 341.jpg written to data_collected_from_google\not_pretty success
# 342.jpg written to data_collected_from_google\not_pretty success
# 343.jpg written to data_collected_from_google\not_pretty success
# 344.jpg written to data_collected_from_google\not_pretty success
# 345.jpg written to data_collected_from_google\not_pretty success
# 346.jpg written to data_collected_from_google\not_pretty success
# 347.jpg written to data_collected_from_google\not_pretty success
# 348.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 349.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 350.jpg written to data_collected_from_google\not_pretty success
# 351.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 352.jpg written to data_collected_from_google\not_pretty success
# 353.jpg written to data_collected_from_google\not_pretty success
# 354.jpg written to data_collected_from_google\not_pretty success
# 355.jpg written to data_collected_from_google\not_pretty success
# 356.jpg written to data_collected_from_google\not_pretty success
# 357.jpg written to data_collected_from_google\not_pretty success
# 358.jpg written to data_collected_from_google\not_pretty success
# 359.jpg written to data_collected_from_google\not_pretty success
# 360.jpg written to data_collected_from_google\not_pretty success
# 361.jpg written to data_collected_from_google\not_pretty success
# 362.jpg written to data_collected_from_google\not_pretty success
# 363.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 364.jpg written to data_collected_from_google\not_pretty success
# 365.jpg written to data_collected_from_google\not_pretty success
# 366.jpg written to data_collected_from_google\not_pretty success
# 367.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 368.jpg written to data_collected_from_google\not_pretty success
# 369.jpg written to data_collected_from_google\not_pretty success
# 370.jpg written to data_collected_from_google\not_pretty success
# 371.jpg written to data_collected_from_google\not_pretty success
# 372.jpg written to data_collected_from_google\not_pretty success
# 373.jpg written to data_collected_from_google\not_pretty success
# 374.jpg written to data_collected_from_google\not_pretty success
# 375.jpg written to data_collected_from_google\not_pretty success
# 376.jpg written to data_collected_from_google\not_pretty success
# 377.jpg written to data_collected_from_google\not_pretty success
# 378.jpg written to data_collected_from_google\not_pretty success
# 379.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 380.jpg written to data_collected_from_google\not_pretty success
# 381.jpg written to data_collected_from_google\not_pretty success
# 382.jpg written to data_collected_from_google\not_pretty success
# 383.jpg written to data_collected_from_google\not_pretty success
# 384.jpg written to data_collected_from_google\not_pretty success
# 385.jpg written to data_collected_from_google\not_pretty success
# 386.jpg written to data_collected_from_google\not_pretty success
# 387.jpg written to data_collected_from_google\not_pretty success
# 388.jpg written to data_collected_from_google\not_pretty success
# 389.jpg written to data_collected_from_google\not_pretty success
# 390.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 391.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 392.jpg written to data_collected_from_google\not_pretty success
# 393.jpg written to data_collected_from_google\not_pretty success
# 394.jpg written to data_collected_from_google\not_pretty success
# 395.jpg written to data_collected_from_google\not_pretty success
# 396.jpg written to data_collected_from_google\not_pretty success
# 397.jpg written to data_collected_from_google\not_pretty success
# 398.jpg written to data_collected_from_google\not_pretty success
# 399.jpg written to data_collected_from_google\not_pretty success
# 400.jpg written to data_collected_from_google\not_pretty success
# 401.jpg written to data_collected_from_google\not_pretty success
# 402.jpg written to data_collected_from_google\not_pretty success
# 403.jpg written to data_collected_from_google\not_pretty success
# 404.jpg written to data_collected_from_google\not_pretty success
# 405.jpg written to data_collected_from_google\not_pretty success
# 406.jpg written to data_collected_from_google\not_pretty success
# 407.jpg written to data_collected_from_google\not_pretty success
# 408.jpg written to data_collected_from_google\not_pretty success
# 409.jpg written to data_collected_from_google\not_pretty success
# 410.jpg written to data_collected_from_google\not_pretty success
# 411.jpg written to data_collected_from_google\not_pretty success
# 412.jpg written to data_collected_from_google\not_pretty success
# 413.jpg written to data_collected_from_google\not_pretty success
# 414.jpg written to data_collected_from_google\not_pretty success
# 415.jpg written to data_collected_from_google\not_pretty success
# 416.jpg written to data_collected_from_google\not_pretty success
# 417.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 418.jpg written to data_collected_from_google\not_pretty success
# 419.jpg written to data_collected_from_google\not_pretty success
# 420.jpg written to data_collected_from_google\not_pretty success
# 421.jpg written to data_collected_from_google\not_pretty success
# 422.jpg written to data_collected_from_google\not_pretty success
# 423.jpg written to data_collected_from_google\not_pretty success
# 424.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 425.jpg written to data_collected_from_google\not_pretty success
# 426.jpg written to data_collected_from_google\not_pretty success
# 427.jpg written to data_collected_from_google\not_pretty success
# 428.jpg written to data_collected_from_google\not_pretty success
# 429.jpg written to data_collected_from_google\not_pretty success
# 430.jpg written to data_collected_from_google\not_pretty success
# 431.jpg written to data_collected_from_google\not_pretty success
# 432.jpg written to data_collected_from_google\not_pretty success
# 433.jpg written to data_collected_from_google\not_pretty success
# 434.jpg written to data_collected_from_google\not_pretty success
# 435.jpg written to data_collected_from_google\not_pretty success
# 436.jpg written to data_collected_from_google\not_pretty success
# Sorry! No Face Detected.
# 437.jpg written to data_collected_from_google\not_pretty success
# 438.jpg written to data_collected_from_google\not_pretty success
# 439.jpg written to data_collected_from_google\not_pretty success
# 440.jpg written to data_collected_from_google\not_pretty success
# 441.jpg written to data_collected_from_google\not_pretty success
# 442.jpg written to data_collected_from_google\not_pretty success
# 443.jpg written to data_collected_from_google\not_pretty success
# 444.jpg written to data_collected_from_google\not_pretty success
# 445.jpg written to data_collected_from_google\not_pretty success
# 446.jpg written to data_collected_from_google\not_pretty success
# data_cascaded\pretty created success..
# 0.jpg written to data_collected_from_google\pretty success
# 1.jpg written to data_collected_from_google\pretty success
# 2.jpg written to data_collected_from_google\pretty success
# 3.jpg written to data_collected_from_google\pretty success
# 4.jpg written to data_collected_from_google\pretty success
# 5.jpg written to data_collected_from_google\pretty success
# 6.jpg written to data_collected_from_google\pretty success
# 7.jpg written to data_collected_from_google\pretty success
# 8.jpg written to data_collected_from_google\pretty success
# 9.jpg written to data_collected_from_google\pretty success
# 10.jpg written to data_collected_from_google\pretty success
# 11.jpg written to data_collected_from_google\pretty success
# 12.jpg written to data_collected_from_google\pretty success
# 13.jpg written to data_collected_from_google\pretty success
# 14.jpg written to data_collected_from_google\pretty success
# 15.jpg written to data_collected_from_google\pretty success
# 16.jpg written to data_collected_from_google\pretty success
# 17.jpg written to data_collected_from_google\pretty success
# 18.jpg written to data_collected_from_google\pretty success
# 19.jpg written to data_collected_from_google\pretty success
# 20.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 21.jpg written to data_collected_from_google\pretty success
# 22.jpg written to data_collected_from_google\pretty success
# 23.jpg written to data_collected_from_google\pretty success
# 24.jpg written to data_collected_from_google\pretty success
# 25.jpg written to data_collected_from_google\pretty success
# 26.jpg written to data_collected_from_google\pretty success
# 27.jpg written to data_collected_from_google\pretty success
# 28.jpg written to data_collected_from_google\pretty success
# 29.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 30.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 31.jpg written to data_collected_from_google\pretty success
# 32.jpg written to data_collected_from_google\pretty success
# 33.jpg written to data_collected_from_google\pretty success
# 34.jpg written to data_collected_from_google\pretty success
# 35.jpg written to data_collected_from_google\pretty success
# 36.jpg written to data_collected_from_google\pretty success
# 37.jpg written to data_collected_from_google\pretty success
# 38.jpg written to data_collected_from_google\pretty success
# 39.jpg written to data_collected_from_google\pretty success
# 40.jpg written to data_collected_from_google\pretty success
# 41.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 42.jpg written to data_collected_from_google\pretty success
# 43.jpg written to data_collected_from_google\pretty success
# 44.jpg written to data_collected_from_google\pretty success
# 45.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 46.jpg written to data_collected_from_google\pretty success
# 47.jpg written to data_collected_from_google\pretty success
# 48.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 49.jpg written to data_collected_from_google\pretty success
# 50.jpg written to data_collected_from_google\pretty success
# 51.jpg written to data_collected_from_google\pretty success
# 52.jpg written to data_collected_from_google\pretty success
# 53.jpg written to data_collected_from_google\pretty success
# 54.jpg written to data_collected_from_google\pretty success
# 55.jpg written to data_collected_from_google\pretty success
# 56.jpg written to data_collected_from_google\pretty success
# 57.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 58.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 59.jpg written to data_collected_from_google\pretty success
# 60.jpg written to data_collected_from_google\pretty success
# 61.jpg written to data_collected_from_google\pretty success
# 62.jpg written to data_collected_from_google\pretty success
# 63.jpg written to data_collected_from_google\pretty success
# 64.jpg written to data_collected_from_google\pretty success
# 65.jpg written to data_collected_from_google\pretty success
# 66.jpg written to data_collected_from_google\pretty success
# 67.jpg written to data_collected_from_google\pretty success
# 68.jpg written to data_collected_from_google\pretty success
# 69.jpg written to data_collected_from_google\pretty success
# 70.jpg written to data_collected_from_google\pretty success
# 71.jpg written to data_collected_from_google\pretty success
# 72.jpg written to data_collected_from_google\pretty success
# 73.jpg written to data_collected_from_google\pretty success
# 74.jpg written to data_collected_from_google\pretty success
# 75.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 76.jpg written to data_collected_from_google\pretty success
# 77.jpg written to data_collected_from_google\pretty success
# 78.jpg written to data_collected_from_google\pretty success
# 79.jpg written to data_collected_from_google\pretty success
# 80.jpg written to data_collected_from_google\pretty success
# 81.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 82.jpg written to data_collected_from_google\pretty success
# 83.jpg written to data_collected_from_google\pretty success
# 84.jpg written to data_collected_from_google\pretty success
# 85.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 86.jpg written to data_collected_from_google\pretty success
# 87.jpg written to data_collected_from_google\pretty success
# 88.jpg written to data_collected_from_google\pretty success
# 89.jpg written to data_collected_from_google\pretty success
# 90.jpg written to data_collected_from_google\pretty success
# 91.jpg written to data_collected_from_google\pretty success
# 92.jpg written to data_collected_from_google\pretty success
# 93.jpg written to data_collected_from_google\pretty success
# 94.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 95.jpg written to data_collected_from_google\pretty success
# 96.jpg written to data_collected_from_google\pretty success
# 97.jpg written to data_collected_from_google\pretty success
# 98.jpg written to data_collected_from_google\pretty success
# 99.jpg written to data_collected_from_google\pretty success
# 100.jpg written to data_collected_from_google\pretty success
# 101.jpg written to data_collected_from_google\pretty success
# 102.jpg written to data_collected_from_google\pretty success
# 103.jpg written to data_collected_from_google\pretty success
# 104.jpg written to data_collected_from_google\pretty success
# 105.jpg written to data_collected_from_google\pretty success
# 106.jpg written to data_collected_from_google\pretty success
# 107.jpg written to data_collected_from_google\pretty success
# 108.jpg written to data_collected_from_google\pretty success
# 109.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 110.jpg written to data_collected_from_google\pretty success
# 111.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 112.jpg written to data_collected_from_google\pretty success
# 113.jpg written to data_collected_from_google\pretty success
# 114.jpg written to data_collected_from_google\pretty success
# 115.jpg written to data_collected_from_google\pretty success
# 116.jpg written to data_collected_from_google\pretty success
# 117.jpg written to data_collected_from_google\pretty success
# 118.jpg written to data_collected_from_google\pretty success
# 119.jpg written to data_collected_from_google\pretty success
# 120.jpg written to data_collected_from_google\pretty success
# 121.jpg written to data_collected_from_google\pretty success
# 122.jpg written to data_collected_from_google\pretty success
# 123.jpg written to data_collected_from_google\pretty success
# 124.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 125.jpg written to data_collected_from_google\pretty success
# 126.jpg written to data_collected_from_google\pretty success
# 127.jpg written to data_collected_from_google\pretty success
# 128.jpg written to data_collected_from_google\pretty success
# 129.jpg written to data_collected_from_google\pretty success
# 130.jpg written to data_collected_from_google\pretty success
# 131.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 132.jpg written to data_collected_from_google\pretty success
# 133.jpg written to data_collected_from_google\pretty success
# 134.jpg written to data_collected_from_google\pretty success
# 135.jpg written to data_collected_from_google\pretty success
# 136.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 137.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 138.jpg written to data_collected_from_google\pretty success
# 139.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 140.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 141.jpg written to data_collected_from_google\pretty success
# 142.jpg written to data_collected_from_google\pretty success
# 143.jpg written to data_collected_from_google\pretty success
# 144.jpg written to data_collected_from_google\pretty success
# 145.jpg written to data_collected_from_google\pretty success
# 146.jpg written to data_collected_from_google\pretty success
# 147.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 148.jpg written to data_collected_from_google\pretty success
# 149.jpg written to data_collected_from_google\pretty success
# 150.jpg written to data_collected_from_google\pretty success
# 151.jpg written to data_collected_from_google\pretty success
# 152.jpg written to data_collected_from_google\pretty success
# 153.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 154.jpg written to data_collected_from_google\pretty success
# 155.jpg written to data_collected_from_google\pretty success
# 156.jpg written to data_collected_from_google\pretty success
# 157.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 158.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 159.jpg written to data_collected_from_google\pretty success
# 160.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 161.jpg written to data_collected_from_google\pretty success
# 162.jpg written to data_collected_from_google\pretty success
# 163.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 164.jpg written to data_collected_from_google\pretty success
# 165.jpg written to data_collected_from_google\pretty success
# 166.jpg written to data_collected_from_google\pretty success
# 167.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 168.jpg written to data_collected_from_google\pretty success
# 169.jpg written to data_collected_from_google\pretty success
# 170.jpg written to data_collected_from_google\pretty success
# 171.jpg written to data_collected_from_google\pretty success
# 172.jpg written to data_collected_from_google\pretty success
# 173.jpg written to data_collected_from_google\pretty success
# 174.jpg written to data_collected_from_google\pretty success
# 175.jpg written to data_collected_from_google\pretty success
# 176.jpg written to data_collected_from_google\pretty success
# 177.jpg written to data_collected_from_google\pretty success
# 178.jpg written to data_collected_from_google\pretty success
# 179.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 180.jpg written to data_collected_from_google\pretty success
# 181.jpg written to data_collected_from_google\pretty success
# 182.jpg written to data_collected_from_google\pretty success
# 183.jpg written to data_collected_from_google\pretty success
# 184.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 185.jpg written to data_collected_from_google\pretty success
# 186.jpg written to data_collected_from_google\pretty success
# 187.jpg written to data_collected_from_google\pretty success
# 188.jpg written to data_collected_from_google\pretty success
# 189.jpg written to data_collected_from_google\pretty success
# 190.jpg written to data_collected_from_google\pretty success
# 191.jpg written to data_collected_from_google\pretty success
# 192.jpg written to data_collected_from_google\pretty success
# 193.jpg written to data_collected_from_google\pretty success
# 194.jpg written to data_collected_from_google\pretty success
# 195.jpg written to data_collected_from_google\pretty success
# 196.jpg written to data_collected_from_google\pretty success
# 197.jpg written to data_collected_from_google\pretty success
# 198.jpg written to data_collected_from_google\pretty success
# 199.jpg written to data_collected_from_google\pretty success
# 200.jpg written to data_collected_from_google\pretty success
# 201.jpg written to data_collected_from_google\pretty success
# 202.jpg written to data_collected_from_google\pretty success
# 203.jpg written to data_collected_from_google\pretty success
# 204.jpg written to data_collected_from_google\pretty success
# 205.jpg written to data_collected_from_google\pretty success
# 206.jpg written to data_collected_from_google\pretty success
# 207.jpg written to data_collected_from_google\pretty success
# 208.jpg written to data_collected_from_google\pretty success
# 209.jpg written to data_collected_from_google\pretty success
# 210.jpg written to data_collected_from_google\pretty success
# 211.jpg written to data_collected_from_google\pretty success
# 212.jpg written to data_collected_from_google\pretty success
# 213.jpg written to data_collected_from_google\pretty success
# 214.jpg written to data_collected_from_google\pretty success
# 215.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 216.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 217.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 218.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 219.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 220.jpg written to data_collected_from_google\pretty success
# 221.jpg written to data_collected_from_google\pretty success
# 222.jpg written to data_collected_from_google\pretty success
# 223.jpg written to data_collected_from_google\pretty success
# 224.jpg written to data_collected_from_google\pretty success
# 225.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 226.jpg written to data_collected_from_google\pretty success
# 227.jpg written to data_collected_from_google\pretty success
# 228.jpg written to data_collected_from_google\pretty success
# 229.jpg written to data_collected_from_google\pretty success
# 230.jpg written to data_collected_from_google\pretty success
# 231.jpg written to data_collected_from_google\pretty success
# 232.jpg written to data_collected_from_google\pretty success
# 233.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 234.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 235.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 236.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# ...
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 277.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 278.jpg written to data_collected_from_google\pretty success
# 279.jpg written to data_collected_from_google\pretty success
# 280.jpg written to data_collected_from_google\pretty success
# 281.jpg written to data_collected_from_google\pretty success
# 282.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 283.jpg written to data_collected_from_google\pretty success
# 284.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 285.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 286.jpg written to data_collected_from_google\pretty success
# 287.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 288.jpg written to data_collected_from_google\pretty success
# 289.jpg written to data_collected_from_google\pretty success
# 290.jpg written to data_collected_from_google\pretty success
# 291.jpg written to data_collected_from_google\pretty success
# 292.jpg written to data_collected_from_google\pretty success
# 293.jpg written to data_collected_from_google\pretty success
# 294.jpg written to data_collected_from_google\pretty success
# 295.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 296.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 297.jpg written to data_collected_from_google\pretty success
# 298.jpg written to data_collected_from_google\pretty success
# 299.jpg written to data_collected_from_google\pretty success
# 300.jpg written to data_collected_from_google\pretty success
# 301.jpg written to data_collected_from_google\pretty success
# 302.jpg written to data_collected_from_google\pretty success
# 303.jpg written to data_collected_from_google\pretty success
# 304.jpg written to data_collected_from_google\pretty success
# 305.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 306.jpg written to data_collected_from_google\pretty success
# 307.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 308.jpg written to data_collected_from_google\pretty success
# 309.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 310.jpg written to data_collected_from_google\pretty success
# 311.jpg written to data_collected_from_google\pretty success
# 312.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 313.jpg written to data_collected_from_google\pretty success
# 314.jpg written to data_collected_from_google\pretty success
# 315.jpg written to data_collected_from_google\pretty success
# 316.jpg written to data_collected_from_google\pretty success
# 317.jpg written to data_collected_from_google\pretty success
# 318.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 319.jpg written to data_collected_from_google\pretty success
# 320.jpg written to data_collected_from_google\pretty success
# 321.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 322.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 323.jpg written to data_collected_from_google\pretty success
# 324.jpg written to data_collected_from_google\pretty success
# 325.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 326.jpg written to data_collected_from_google\pretty success
# 327.jpg written to data_collected_from_google\pretty success
# 328.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 329.jpg written to data_collected_from_google\pretty success
# 330.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 331.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 332.jpg written to data_collected_from_google\pretty success
# 333.jpg written to data_collected_from_google\pretty success
# 334.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 335.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 336.jpg written to data_collected_from_google\pretty success
# 337.jpg written to data_collected_from_google\pretty success
# 338.jpg written to data_collected_from_google\pretty success
# 339.jpg written to data_collected_from_google\pretty success
# 340.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 341.jpg written to data_collected_from_google\pretty success
# 342.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 343.jpg written to data_collected_from_google\pretty success
# 344.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 345.jpg written to data_collected_from_google\pretty success
# 346.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 347.jpg written to data_collected_from_google\pretty success
# 348.jpg written to data_collected_from_google\pretty success
# 349.jpg written to data_collected_from_google\pretty success
# 350.jpg written to data_collected_from_google\pretty success
# 351.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 352.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 353.jpg written to data_collected_from_google\pretty success
# 354.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 355.jpg written to data_collected_from_google\pretty success
# 356.jpg written to data_collected_from_google\pretty success
# 357.jpg written to data_collected_from_google\pretty success
# 358.jpg written to data_collected_from_google\pretty success
# 359.jpg written to data_collected_from_google\pretty success
# 360.jpg written to data_collected_from_google\pretty success
# 361.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 362.jpg written to data_collected_from_google\pretty success
# 363.jpg written to data_collected_from_google\pretty success
# 364.jpg written to data_collected_from_google\pretty success
# 365.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 366.jpg written to data_collected_from_google\pretty success
# 367.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 368.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 369.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 370.jpg written to data_collected_from_google\pretty success
# 371.jpg written to data_collected_from_google\pretty success
# 372.jpg written to data_collected_from_google\pretty success
# 373.jpg written to data_collected_from_google\pretty success
# 374.jpg written to data_collected_from_google\pretty success
# 375.jpg written to data_collected_from_google\pretty success
# 376.jpg written to data_collected_from_google\pretty success
# 377.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 378.jpg written to data_collected_from_google\pretty success
# 379.jpg written to data_collected_from_google\pretty success
# 380.jpg written to data_collected_from_google\pretty success
# 381.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 382.jpg written to data_collected_from_google\pretty success
# 383.jpg written to data_collected_from_google\pretty success
# 384.jpg written to data_collected_from_google\pretty success
# 385.jpg written to data_collected_from_google\pretty success
# 386.jpg written to data_collected_from_google\pretty success
# 387.jpg written to data_collected_from_google\pretty success
# 388.jpg written to data_collected_from_google\pretty success
# 389.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 390.jpg written to data_collected_from_google\pretty success
# 391.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 392.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 393.jpg written to data_collected_from_google\pretty success
# 394.jpg written to data_collected_from_google\pretty success
# 395.jpg written to data_collected_from_google\pretty success
# 396.jpg written to data_collected_from_google\pretty success
# 397.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 398.jpg written to data_collected_from_google\pretty success
# 399.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 400.jpg written to data_collected_from_google\pretty success
# 401.jpg written to data_collected_from_google\pretty success
# 402.jpg written to data_collected_from_google\pretty success
# 403.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 404.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 405.jpg written to data_collected_from_google\pretty success
# 406.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 407.jpg written to data_collected_from_google\pretty success
# 408.jpg written to data_collected_from_google\pretty success
# 409.jpg written to data_collected_from_google\pretty success
# 410.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 411.jpg written to data_collected_from_google\pretty success
# 412.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 413.jpg written to data_collected_from_google\pretty success
# 414.jpg written to data_collected_from_google\pretty success
# 415.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 416.jpg written to data_collected_from_google\pretty success
# 417.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 418.jpg written to data_collected_from_google\pretty success
# 419.jpg written to data_collected_from_google\pretty success
# 420.jpg written to data_collected_from_google\pretty success
# 421.jpg written to data_collected_from_google\pretty success
# 422.jpg written to data_collected_from_google\pretty success
# 423.jpg written to data_collected_from_google\pretty success
# 424.jpg written to data_collected_from_google\pretty success
# 425.jpg written to data_collected_from_google\pretty success
# 426.jpg written to data_collected_from_google\pretty success
# 427.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 428.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# Sorry! No Face Detected.
# 429.jpg written to data_collected_from_google\pretty success
# 430.jpg written to data_collected_from_google\pretty success
# 431.jpg written to data_collected_from_google\pretty success
# 432.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 433.jpg written to data_collected_from_google\pretty success
# 434.jpg written to data_collected_from_google\pretty success
# 435.jpg written to data_collected_from_google\pretty success
# 436.jpg written to data_collected_from_google\pretty success
# 437.jpg written to data_collected_from_google\pretty success
# 438.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 439.jpg written to data_collected_from_google\pretty success
# 440.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 441.jpg written to data_collected_from_google\pretty success
# 442.jpg written to data_collected_from_google\pretty success
# 443.jpg written to data_collected_from_google\pretty success
# 444.jpg written to data_collected_from_google\pretty success
# 445.jpg written to data_collected_from_google\pretty success
# 446.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 447.jpg written to data_collected_from_google\pretty success
# 448.jpg written to data_collected_from_google\pretty success
# 449.jpg written to data_collected_from_google\pretty success
# 450.jpg written to data_collected_from_google\pretty success
# 451.jpg written to data_collected_from_google\pretty success
# 452.jpg written to data_collected_from_google\pretty success
# 453.jpg written to data_collected_from_google\pretty success
# 454.jpg written to data_collected_from_google\pretty success
# 455.jpg written to data_collected_from_google\pretty success
# 456.jpg written to data_collected_from_google\pretty success
# 457.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 458.jpg written to data_collected_from_google\pretty success
# 459.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 460.jpg written to data_collected_from_google\pretty success
# 461.jpg written to data_collected_from_google\pretty success
# 462.jpg written to data_collected_from_google\pretty success
# 463.jpg written to data_collected_from_google\pretty success
# 464.jpg written to data_collected_from_google\pretty success
# 465.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 466.jpg written to data_collected_from_google\pretty success
# 467.jpg written to data_collected_from_google\pretty success
# 468.jpg written to data_collected_from_google\pretty success
# 469.jpg written to data_collected_from_google\pretty success
# 470.jpg written to data_collected_from_google\pretty success
# 471.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 472.jpg written to data_collected_from_google\pretty success
# 473.jpg written to data_collected_from_google\pretty success
# 474.jpg written to data_collected_from_google\pretty success
# 475.jpg written to data_collected_from_google\pretty success
# 476.jpg written to data_collected_from_google\pretty success
# 477.jpg written to data_collected_from_google\pretty success
# 478.jpg written to data_collected_from_google\pretty success
# 479.jpg written to data_collected_from_google\pretty success
# 480.jpg written to data_collected_from_google\pretty success
# 481.jpg written to data_collected_from_google\pretty success
# 482.jpg written to data_collected_from_google\pretty success
# 483.jpg written to data_collected_from_google\pretty success
# 484.jpg written to data_collected_from_google\pretty success
# 485.jpg written to data_collected_from_google\pretty success
# 486.jpg written to data_collected_from_google\pretty success
# 487.jpg written to data_collected_from_google\pretty success
# 488.jpg written to data_collected_from_google\pretty success
# 489.jpg written to data_collected_from_google\pretty success
# 490.jpg written to data_collected_from_google\pretty success
# Sorry! No Face Detected.
# 491.jpg written to data_collected_from_google\pretty success
# 492.jpg written to data_collected_from_google\pretty success
# 493.jpg written to data_collected_from_google\pretty success
# 494.jpg written to data_collected_from_google\pretty success
# 495.jpg written to data_collected_from_google\pretty success
# 496.jpg written to data_collected_from_google\pretty success
# 497.jpg written to data_collected_from_google\pretty success
# 498.jpg written to data_collected_from_google\pretty success
# 499.jpg written to data_collected_from_google\pretty success
# 500.jpg written to data_collected_from_google\pretty success
# 501.jpg written to data_collected_from_google\pretty success
# 502.jpg written to data_collected_from_google\pretty success
# 503.jpg written to data_collected_from_google\pretty success
# 504.jpg written to data_collected_from_google\pretty success
